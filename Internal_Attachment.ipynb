# %% [markdown]
# ## importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/HPPC/Downloads/cleaned_sbt_japan.csv")
df.head()
# Out:
#     car_brand car_model  mileage_km  engine_size_cc            transmission  \
# 0        AUDI  TT COUPE       56000            2000  Automatic Transmission
# 1  VOLKSWAGEN      GOLF       48000            1200  Automatic Transmission
# 2         KIA    MOHAVE       37000            2959  Automatic Transmission
# 3         BMW        i3       51000             900  Automatic Transmission
# 4     GENESIS       G80      120000            2497  Automatic Transmission
#
#   fuel_type steering_type drive_train no_of_seats no_of_doors  ...  \
# 0    Petrol           RHD         4WD     4 Seats     3 Doors  ...
# 1    Petrol           RHD       Other     5 Seats     5 Doors  ...
# 2    Diesel           LHD         4WD     7 Seats     4 Doors  ...
# 3    Hybrid           RHD       Other     4 Seats     5 Doors  ...
# 4    Petrol           LHD         4WD     5 Seats     4 Doors  ...
#
#   Power Steering  Air Conditioner  Navigation  Air Bag  \
# ...

# %%
list(df.columns)
# Out:
# ['car_brand',
#  'car_model',
#  'mileage_km',
#  'engine_size_cc',
#  'transmission',
#  'fuel_type',
#  'steering_type',
#  'drive_train',
#  'no_of_seats',
#  'no_of_doors',
#  'body_type',
#  'Power Steering',
#  'Air Conditioner',
#  'Navigation',
#  'Air Bag',
#  'Anti-Lock Brake System',
#  'Fog Lights',
#  'Power Windows',
#  'Alloy Wheels',
#  'year',
#  'price(Ksh)']

# %% [markdown]
# #### What is the average price of each manufacturer

# %%
average_prices = df.groupby('car_brand')['price(Ksh)'].mean()
average_prices.round(2)
# Out:
# car_brand
# ALFA            5809306.64
# AMG             8260609.94
# AUDI            5937714.57
# Abarth          3713165.07
# Aston          12131615.79
# BMW             7065283.98
# BYD             5804562.00
# Bentley        11719027.49
# Buick           4753584.00
# CADILLAC        7429580.00
# CHERY           1849833.00
# CHEVROLET       8481098.05
# CHRYSLER        6451347.93
# CITROEN         3544252.55
# DAIHATSU        2387523.84
# DODGE           7612084.31
# FAW            12155849.00
# FERRARI        12155849.00
# FIAT            3017574.44
# FORD            5667070.83
# GELLY           1707538.00
# GENESIS         6648423.16
# HONDA           3339613.20
# HYUNDAI         5070702.77
# INFINITI        8329335.00
# ISUZU           6118440.30
# JAGUAR          7706342.90
# JEEP            6711750.53
# KIA             5464083.98
# LAND            7849586.78
# LEADING         8596999.25
# LEXUS           7072870.93
# Lamborghini    12155849.00
# Lotus           9892204.55
# ...

# %% [markdown]
# #### Does the transmission affect car price

# %%
transmission_prices = df.groupby('transmission')['price(Ksh)'].mean()

plt.figure(figsize = (8, 6))
plt.bar(transmission_prices.index,transmission_prices.values,color = ['skyblue', 'salmon'])
plt.xlabel('Transmission Type')
plt.ylabel('Average Price (Ksh)')
plt.title('Average car prices by transmission type')
plt.grid(axis = 'y',linestyle = '--', alpha = 0.7)
plt.show()

# %% [markdown]
# #### Effects of mileage on car prices

# %%
mileage = df.groupby('mileage_km')['price(Ksh)'].mean()
plt.figure(figsize = (8,6))
plt.scatter(mileage.index, mileage.values, marker = 'o', color = 'b' )
plt.xlabel('Mileage (miles)')
plt.ylabel('Price ($)')
plt.title('Effect of Mileage on Car Prices')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Correlation Matrix

# %%
import seaborn as sns

# %%
# Select only numeric columns for correlation calculation
numeric_columns = df.select_dtypes(include=[np.number])
# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()
# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
